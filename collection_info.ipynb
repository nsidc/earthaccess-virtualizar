# %% [markdown]
# # Earthdata Crawler
#
# Check the following for every collection:
# - Presence of cloud opendap URL
# - Presence of a DMR++ URL
# - Whether DMR++ is openable by VirtualiZarr's DMR++ parser
# - Whether DMR++ is downloadable
# - (not yet) Quality of dmrpp (are they flattened?)
#
# Note: Borrowed `get_info` from https://github.com/opengeos/NASA-Earth-Data/blob/main/nasa_earth_data.py

# %%
import logging
import requests

import earthaccess
import pandas as pd
import virtualizarr as vz
from dask.distributed import LocalCluster, Client
from tqdm.notebook import tqdm


# Handy text formatting codes.
bold_start = '\033[1m'
bold_end = '\033[0m'

# %% [markdown]
# ## Retrieve all collections.

# %%
_ = earthaccess.login()

# %%
# %%time
collections = earthaccess.search_datasets(keyword="*")
len(collections)
# Out:
# CPU times: user 2.14 s, sys: 407 ms, total: 2.55 s
# Wall time: 2min 28s
# 9903

# %% [markdown]
# ## Set up session, cluster, and logging.

# %%
# An fsspec session will be used for VirtualiZarr parsing.
fs = earthaccess.get_fsspec_https_session()

# %%
# Start a Dask cluster to be used for processing Earthdata collections in parallel.
if "dask_client" not in locals():
    # cluster = LocalCluster(threads_per_worker=1)
    cluster = LocalCluster(processes=True)
    dask_client = Client(cluster)

dask_client
# Out:
# <Client: 'tcp://127.0.0.1:38631' processes=4 threads=4, memory=3.71 GiB>

# %%
# Retrieve logger so we can log messages during dask jobs.
logger = logging.getLogger("distributed.worker")

# %%
# There will be many HTTP 404 "Not Found" Errors so let's not print them.
class MyFilter(logging.Filter):
    def filter(self, record):
        # Example: Filter out messages containing "debug"
        return "Error while downloading the file" not in record.getMessage()

logging.getLogger("earthaccess.store").addFilter(MyFilter())

# %% [markdown]
# ## Main logic is in these functions.

# %%
def get_collection_info(one_collection):
    info = {}
    info["ShortName"] = one_collection["umm"]["ShortName"]
    info["concept-id"] = one_collection["meta"]["concept-id"]
    info["provider-id"] = one_collection["meta"]["provider-id"]

    return info

# %%
def get_single_granule_from_collection(collection_concept_id: str) -> tuple[earthaccess.DataGranule | None, []]:
    """Return a single granule and its associated URLs."""
    try:
        a_granule = earthaccess.search_data(
            concept_id=collection_concept_id,
            count=1
        )
    except RuntimeError as err:
        logger.warning(f"For [{collection_concept_id}]: {err}")
        return None, []
        

    try:
        links = a_granule[0].data_links(access="indirect")
    except IndexError as err:
        logger.warning(f"For [{collection_concept_id}]: {err}")
        return None, []
    
    return a_granule[0], links

# %%
def check_dmrpp_from_url(a_url: str) -> tuple[bool, bool]:
    """Try opening, and if not openable, then at least try downloading, a DMR++ file.
    
    Returns:
        A tuple containing a bool (whether the DMR++ was able to be downloaded) 
        and a bool (whether the DMR++ was able to be opened using 
        `virtualizarr.open_virtual_dataset()`).
    """
    downloadable = False
    openable = False
    
    dmrpp_url = a_url + ".dmrpp"
    logger.info(f"check_dmrpp_for_a_url for {dmrpp_url}")

    # TEST 1 - Try opening the DMR++ with VirtualiZarr
    try:
        opened_dmrpp = vz.open_virtual_dataset(
            dmrpp_url, 
            filetype="dmrpp", 
            indexes={}, 
            reader_options={"storage_options": fs.storage_options}
        )
        downloadable = True
        openable = True
        logger.info("Opened DMR++ with VirtualiZarr.")
        
    except FileNotFoundError as err:
        logger.info("DMR++ not found.")

    # TEST 2 - Try downloading the DMR++
    except Exception as err:
        logging.info(f"Exception occurred when opening DMR++: {err}. Trying download..")
        # If opening didn't work, let's just try downloading
        try:
            files = earthaccess.download(dmrpp_url, "./dmrpp/", pqdm_kwargs={"disable": True})
            downloadable = True
            logger.info("Downloaded DMR++.")
        except Exception as errh:
            logger.warning(f"DMR++ exists but exception {errh} occurred when attempting download of {dmrpp_url}.")
        except RuntimeError as err:
            logger.warning(f"DMR++ exists but unexpected RuntimeError occurred when attempting download of {dmrpp_url}.")
            raise err

    # TEST 3 - Traverse all groups.
    # TODO - walk groups inside the DMR++, and pass each group to virtualizarr.open_virtual_dataset().
            
    return downloadable, openable

# %%
def inspect_collection(a_collection: earthaccess.DataCollection) -> tuple[dict, dict]:
    """Determine the accessibility of DMR++ related attributes of an Collection."""
    collection_info = get_collection_info(a_collection)
    concept_id = collection_info['concept-id']

    # Check if a cloud opendap or .dmrpp URL exists.
    url_results = {
        "concept_id": concept_id,
        "provider_id": collection_info['provider-id'],
        "cloud_opendap_url": None,
        "dmrpp_url_in_cmr": None,
        "downloadable_dmrpp": False,
        "openable_dmrpp": False
    }
    
    a_granule, the_get_data_urls = get_single_granule_from_collection(concept_id)
    if a_granule is not None:
        try:
            url_fields = a_granule['umm']['RelatedUrls']
        except KeyError:
            logger.warning(f"For {concept_id}: Keys ['umm']['RelatedUrls'] were not found.")
            return collection_info, url_results
            
        for url_field in url_fields:  # Iterate over RelatedUrls in each request step
            url = url_field['URL']
            logger.info(f"url-{url}")
            
            if url.startswith("https://opendap.earthdata.nasa.gov/"):
                url_results["cloud_opendap_url"] = url
                
            elif url.endswith(".dmrpp"):
                url_results["dmrpp_url_in_cmr"] = url
    
            if url in the_get_data_urls:
                downloaded, opened = check_dmrpp_from_url(url)
                if downloaded:
                    url_results["downloadable_dmrpp"] = True
                if opened:
                    url_results["openable_dmrpp"] = True
                
    return collection_info, url_results

# %% [markdown]
# ## Cycle through collections.

# %%
collections_to_check = collections
num_collections = len(collections_to_check)

# %%
# %%time
futures = dask_client.map(inspect_collection, collections_to_check) # Map the function to a sequence of inputs
inspection_results = dask_client.gather(futures) # Collect the results
# Out:
# /srv/conda/envs/notebook/lib/python3.11/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 81.38 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# 2025-04-30 19:36:11,722 - distributed.worker - WARNING - For [C2780764136-LANCEMODIS]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 19:36:32,128 - distributed.worker - WARNING - For [C1514684539-LANCEAMSR2]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 19:41:59,114 - distributed.worker - WARNING - For C191856320-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 19:42:23,783 - distributed.worker - WARNING - For C191856337-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 19:48:42,551 - distributed.worker - WARNING - For C3352252530-LAADS: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 19:48:47,817 - distributed.worker - WARNING - For C3348072630-LAADS: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30
LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:24:03,797 - distributed.worker - WARNING - For [C1657477341-OMINRT]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 21:28:05,602 - distributed.worker - WARNING - For [C1233769001-GES_DISC]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 21:29:38,429 - distributed.worker - WARNING - For [C1427015288-LANCEMODIS]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 21:29:39,160 - distributed.worker - WARNING - For C179031521-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:38:28,079 - distributed.worker - WARNING - For C179031513-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:38:28,080 - distributed.worker - WARNING - For C179031511-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:40:59,999 - distributed.worker - WARNING - For C184964541-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:41:00,274 - distributed.worker - WARNING - For C184964544-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:50:17,931 - distributed.worker - WARNING - For [C1607549631-ASIPS]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 21:50:29,556 - distributed.worker - WARNING - For [C2003160566-ASIPS]: {"errors":["An Internal Error has occurred."]}
# 2025-04-30 21:50:31,081 - distributed.worker - WARNING - For [C1607563719-ASIPS]: {"errors":["An Internal Error has occurred."]}
# ERROR:earthaccess.store:Error while downloading the file coherence.dmrpp
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/earthaccess/store.py", line 678, in _download_file
#     r.raise_for_status()
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 502 Server Error: Bad Gateway for url: https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/coherence.dmrpp
# 2025-04-30 21:50:32,454 - distributed.worker - WARNING - DMR++ exists but exception  occurred when attempting download of https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/coherence.dmrpp.
# ERROR:earthaccess.store:Error while downloading the file connectedComponents.dmrpp
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/earthaccess/store.py", line 678, in _download_file
#     r.raise_for_status()
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 502 Server Error: Bad Gateway for url: https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/connectedComponents.dmrpp
# 2025-04-30 21:50:36,719 - distributed.worker - WARNING - DMR++ exists but exception  occurred when attempting download of https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/connectedComponents.dmrpp.
# ERROR:earthaccess.store:Error while downloading the file amplitude.dmrpp
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/earthaccess/store.py", line 678, in _download_file
#     r.raise_for_status()
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 502 Server Error: Bad Gateway for url: https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/amplitude.dmrpp
# 2025-04-30 21:50:36,722 - distributed.worker - WARNING - DMR++ exists but exception  occurred when attempting download of https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/amplitude.dmrpp.
# ERROR:earthaccess.store:Error while downloading the file unwrappedPhase.dmrpp
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/earthaccess/store.py", line 678, in _download_file
#     r.raise_for_status()
#   File "/srv/conda/envs/notebook/lib/python3.11/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 502 Server Error: Bad Gateway for url: https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/unwrappedPhase.dmrpp
# 2025-04-30 21:50:37,228 - distributed.worker - WARNING - DMR++ exists but exception  occurred when attempting download of https://services.asf.alaska.edu/geospatial/reformat?product=S1-GUNW-A-R-145-tops-20141015_20141003-150859-00041E_00036N-PP-5791-v2_0_5.nc&layer=science/grids/data/unwrappedPhase.dmrpp.
# 2025-04-30 21:50:37,309 - distributed.worker - WARNING - For C182161246-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:50:37,623 - distributed.worker - WARNING - For C182161249-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 21:51:03,321 - distributed.worker - WARNING - For C2450786986-ASF: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:01:44,127 - distributed.worker - WARNING - For C188637668-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:03:57,034 - distributed.worker - WARNING - For C43677727-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:03:57,421 - distributed.worker - WARNING - For C188637670-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:03:57,994 - distributed.worker - WARNING - For C43677728-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:05:00,816 - distributed.worker - WARNING - For C43677732-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:05:07,351 - distributed.worker - WARNING - For C43677733-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:06:03,761 - distributed.worker - WARNING - For C188637672-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:06:59,096 - distributed.worker - WARNING - For C43677738-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:07:00,714 - distributed.worker - WARNING - For C73016614-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:13:00,342 - distributed.worker - WARNING - For C1288777498-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:13:42,353 - distributed.worker - WARNING - For C191476554-LARC: Keys ['umm']['RelatedUrls'] were not found.
# 2025-04-30 22:13:43,984 - distributed.worker - WARNING - For C191476555-LARC: Keys ['umm']['RelatedUrls'] were not found.
# CPU times: user 12min 36s, sys: 1min 27s, total: 14min 4s
# Wall time: 2h 52min 40s

# %%
# dask_client.get_worker_logs()

# %% [markdown]
# ## Wrangle the results into a summary

# %%
expanded_results = []
for result in inspection_results:
    collection_info_dict = result[0]
    url_results_dict = result[1]
    
    expanded_results.append((
        url_results_dict["concept_id"], 
        url_results_dict["provider_id"], 
        url_results_dict["cloud_opendap_url"], 
        url_results_dict["dmrpp_url_in_cmr"], 
        url_results_dict["downloadable_dmrpp"], 
        url_results_dict["openable_dmrpp"]
    ))

results_df = pd.DataFrame.from_dict(expanded_results)
results_df = results_df.rename(columns={
    0: "collection_id", 
    1: "provider_id", 
    2: "cloud_opendap_url", 
    3: "dmrpp_url_in_cmr",
    4: "downloadable_dmrpp", 
    5: "openable_dmrpp"}
)

# %%
results_df.head()
# Out:
#          collection_id provider_id  \
# 0  C2763266360-LPCLOUD     LPCLOUD
# 1    C1964798938-LAADS       LAADS
# 2  C2343115666-LPCLOUD     LPCLOUD
# 3  C2408750690-LPCLOUD     LPCLOUD
# 4  C1996881146-POCLOUD     POCLOUD
#
#                                    cloud_opendap_url  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  https://opendap.earthdata.nasa.gov/collections...
# 4  https://opendap.earthdata.nasa.gov/providers/P...
#
#                                     dmrpp_url_in_cmr  downloadable_dmrpp  \
# 0                                               None               False
# 1                                               None               False
# 2                                               None               False
# 3  s3://lp-prod-public/EMITL2ARFL.001/EMIT_L2A_RF...                True
# 4                                               None                True
#
#    openable_dmrpp
# 0           False
# 1           False
# 2           False
# 3            True
# 4            True

# %%
results_df[results_df["cloud_opendap_url"].notnull()]
# Out:
#             collection_id provider_id  \
# 3     C2408750690-LPCLOUD     LPCLOUD
# 4     C1996881146-POCLOUD     POCLOUD
# 11    C2408009906-LPCLOUD     LPCLOUD
# 33    C2075141684-POCLOUD     POCLOUD
# 40    C2076114664-LPCLOUD     LPCLOUD
# ...                   ...         ...
# 9501  C2013583732-POCLOUD     POCLOUD
# 9502  C2013557893-POCLOUD     POCLOUD
# 9503  C2013584708-POCLOUD     POCLOUD
# 9504  C2013583906-POCLOUD     POCLOUD
# 9885  C3363058972-POCLOUD     POCLOUD
#
#                                       cloud_opendap_url  \
# 3     https://opendap.earthdata.nasa.gov/collections...
# 4     https://opendap.earthdata.nasa.gov/providers/P...
# 11    https://opendap.earthdata.nasa.gov/collections...
# 33    https://opendap.earthdata.nasa.gov/collections...
# 40    https://opendap.earthdata.nasa.gov/collections...
# ...                                                 ...
# 9501  https://opendap.earthdata.nasa.gov/providers/P...
# 9502  https://opendap.earthdata.nasa.gov/providers/P...
# 9503  https://opendap.earthdata.nasa.gov/providers/P...
# 9504  https://opendap.earthdata.nasa.gov/providers/P...
# 9885  https://opendap.earthdata.nasa.gov/collections...
#
#                                        dmrpp_url_in_cmr  downloadable_dmrpp  \
# 3     s3://lp-prod-public/EMITL2ARFL.001/EMIT_L2A_RF...                True
# 4                                                  None                True
# 11    s3://lp-prod-public/EMITL1BRAD.001/EMIT_L1B_RA...                True
# 33                                                 None                True
# 40                                                 None                True
# ...                                                 ...                 ...
# 9501                                               None                True
# 9502                                               None                True
# 9503                                               None                True
# 9504                                               None                True
# 9885                                               None                True
#
#       openable_dmrpp
# 3               True
# 4               True
# 11              True
# 33              True
# 40              True
# ...              ...
# 9501            True
# 9502            True
# 9503            True
# 9504            True
# 9885            True
#
# [1272 rows x 6 columns]

# %%
results_df[results_df["dmrpp_url_in_cmr"].notnull()]["dmrpp_url_in_cmr"].to_list()
# Out:
# ['s3://lp-prod-public/EMITL2ARFL.001/EMIT_L2A_RFL_001_20220810T034103_2222203_001/EMIT_L2A_MASK_001_20220810T034103_2222203_001.nc.dmrpp',
#  's3://lp-prod-public/EMITL1BRAD.001/EMIT_L1B_RAD_001_20220810T034103_2222203_001/EMIT_L1B_OBS_001_20220810T034103_2222203_001.nc.dmrpp',
#  's3://lp-prod-protected/VNP09GA.002/VNP09GA.A2012019.h23v01.002.2023122181913/VNP09GA.A2012019.h23v01.002.2023122181913.h5.dmrpp',
#  's3://lp-prod-protected/VNP14A1.002/VNP14A1.A2012019.h15v00.002.2023121192419/VNP14A1.A2012019.h15v00.002.2023121192419.h5.dmrpp',
#  's3://lp-prod-protected/VNP21A1D.002/VNP21A1D.A2012019.h10v07.002.2023131141704/VNP21A1D.A2012019.h10v07.002.2023131141704.h5.dmrpp',
#  's3://lp-prod-protected/VNP21A1N.002/VNP21A1N.A2012019.h08v09.002.2023131141643/VNP21A1N.A2012019.h08v09.002.2023131141643.h5.dmrpp',
#  's3://lp-prod-protected/VJ114.002/VJ114.A2018005.0000.002.2022252033022/VJ114.A2018005.0000.002.2022252033022.nc.dmrpp',
#  's3://lp-prod-protected/VNP14.002/VNP14.A2012023.1006.002.2023121200640/VNP14.A2012023.1006.002.2023121200640.nc.dmrpp',
#  's3://lp-prod-protected/VNP13A1.002/VNP13A1.A2012017.h26v07.002.2023201191339/VNP13A1.A2012017.h26v07.002.2023201191339.h5.dmrpp',
#  's3://lp-prod-protected/VNP43IA4.002/VNP43IA4.A2012019.h14v01.002.2024089104052/VNP43IA4.A2012019.h14v01.002.2024089104052.h5.dmrpp',
#  's3://lp-prod-protected/VNP15A2H.002/VNP15A2H.A2012017.h26v02.002.2024106202940/VNP15A2H.A2012017.h26v02.002.2024106202940.h5.dmrpp',
#  's3://lp-prod-protected/VNP09A1.002/VNP09A1.A2012017.h30v10.002.2024106202818/VNP09A1.A2012017.h30v10.002.2024106202818.h5.dmrpp',
#  's3://lp-prod-protected/VNP09H1.002/VNP09H1.A2012017.h02v11.002.2024106202816/VNP09H1.A2012017.h02v11.002.2024106202816.h5.dmrpp',
F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2O3CRSWCF.1/2020/TROPESS_CrIS-SNPP_L2_Standard_O3_20200802_MUSES_R1p9_SC_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2O3CRSWCFHI.1/2020/TROPESS_CrIS-SNPP_L2_Standard_O3_20200911_MUSES_R1p9_SC_WCFHI_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2PANCRSWCF.1/2020/TROPESS_CrIS-SNPP_L2_Standard_PAN_20200802_MUSES_R1p9_SC_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2PANCRSWCFHI.1/2020/TROPESS_CrIS-SNPP_L2_Standard_PAN_20200911_MUSES_R1p9_SC_WCFHI_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2CH4CRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_CH4_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2COCRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_CO_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2H2OCRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_H2O_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2HDOCRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_HDO_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2NH3CRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_NH3_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2O3CRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_O3_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2PANCRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_PAN_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/TROPESS_Special/TRPSDL2TATMCRSAUS.1/2019/TROPESS_CrIS-SNPP_L2_Standard_TATM_20191101_MUSES_R1p9_SC_AUS_F0p1.nc.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/GPM_L3/GPM_3GPROFF14SSMI_CLIM.07/1997/3A-CLIM-MO.F14.SSMI.GRID2021R1.19970501-S000000-E235959.05.V07A.HDF5.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/GPM_L3/GPM_3GPROFF14SSMI_DAY_CLIM.07/1997/05/3A-CLIM-DAY.F14.SSMI.GRID2021R1.19970507-S000000-E235959.127.V07A.HDF5.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/GPM_L3/GPM_3GPROFF15SSMI_CLIM.07/2000/3A-CLIM-MO.F15.SSMI.GRID2021R1.20000201-S000000-E235959.02.V07A.HDF5.dmrpp',
#  's3://gesdisc-cumulus-prod-protected/S5P_TROPOMI_Level2/S5P_L2__O3__PR_HiR.2/2021/320/S5P_OFFL_L2__O3__PR_20211116T033235_20211116T051404_21207_02_020301_20211118T005104.nc.dmrpp']

# %%
num_url_results = results_df.shape[0]

summary_stats = {}

num_cloud_opendap_urls = results_df["cloud_opendap_url"].notnull().sum()
num_non_cloud_opendap_urls = results_df["dmrpp_url_in_cmr"].notnull().sum()
num_downloadable_dmrpp = results_df["downloadable_dmrpp"].sum()
num_openable_dmrpp = results_df["openable_dmrpp"].sum()

fraction_downloadable_collections = num_downloadable_dmrpp / num_collections * 100
fraction_openable_collections = num_openable_dmrpp / num_collections * 100
fraction_downloadable_urls = num_downloadable_dmrpp / num_url_results * 100
fraction_openable_urls = num_openable_dmrpp / num_url_results * 100

print(f"Number cloud opendap URLs: {num_cloud_opendap_urls}")
print(f"Number dmr++ URLs in CMR: {num_non_cloud_opendap_urls}")
print(f"Fraction of downloadable DMR++ files (by appending '.dmrpp') found: {num_downloadable_dmrpp} out of {num_collections} datasets" 
      f"({fraction_downloadable_collections:0.0f} %) and {num_url_results} URLs ({fraction_downloadable_urls:0.0f} %).")
print(f"Fraction of openable DMR++ files (by appending '.dmrpp') found: {num_openable_dmrpp} out of {num_collections} datasets" 
      f"({fraction_openable_collections:0.0f} %) and {num_url_results} URLs ({fraction_openable_urls:0.0f} %).")
# Out:
# Number cloud opendap URLs: 1272
# Number dmr++ URLs in CMR: 349
# Fraction of downloadable DMR++ files (by appending '.dmrpp') found: 2101 out of 9903 datasets(21 %) and 9903 URLs (21 %).
# Fraction of openable DMR++ files (by appending '.dmrpp') found: 1499 out of 9903 datasets(15 %) and 9903 URLs (15 %).
